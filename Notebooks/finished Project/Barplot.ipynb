# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df2015 = pd.read_csv("/Users/janik.sdt/Documents/Is-the-world-happy/Datasets/Raw Data/2015.csv")
df2016 = pd.read_csv("/Users/janik.sdt/Documents/Is-the-world-happy/Datasets/Raw Data/2016.csv")
df2017 = pd.read_csv("/Users/janik.sdt/Documents/Is-the-world-happy/Datasets/Raw Data/2017.csv")
df2018 = pd.read_csv("/Users/janik.sdt/Documents/Is-the-world-happy/Datasets/Raw Data/2018.csv")
df2019 = pd.read_csv("/Users/janik.sdt/Documents/Is-the-world-happy/Datasets/Raw Data/2019.csv")

# %%
# Set the style of the visualization
sns.set_style("whitegrid")

# Create the bar plot using Seaborn
plt.figure(figsize=(12, 8))
sns.barplot(x='Happiness Score', y='Region', data=df2015, palette='coolwarm')
  # Label the Diagramm
plt.xlabel('Happiness Score', fontsize=14)
plt.ylabel('Region', fontsize=14)
plt.title('Happiness Score by Region', fontsize=16)
plt.tight_layout()
plt.show()
# Out:
# /var/folders/3f/n2rwh49d413bhwkgtvznx7qc0000gn/T/ipykernel_16638/2434219631.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Happiness Score', y='Region', data=df2015, palette='coolwarm')

# %%
def topandlast10(df):
    dftop = df.head(10)
    dflast = df.tail(10)
    dfcombined = pd.concat([dftop,dflast])
    return dfcombined

# %%
dflist = [df2015,df2016]

for df in dflist:
    dfcountries = topandlast10(df)
    sns.barplot(x="Happiness Score", y='Country', data=dfcountries, palette='coolwarm')
# Out:
# /var/folders/3f/n2rwh49d413bhwkgtvznx7qc0000gn/T/ipykernel_16638/3105413625.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x="Happiness Score", y='Country', data=dfcountries, palette='coolwarm')
# /var/folders/3f/n2rwh49d413bhwkgtvznx7qc0000gn/T/ipykernel_16638/3105413625.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x="Happiness Score", y='Country', data=dfcountries, palette='coolwarm')

# %%
medium = [
    df2015.loc[:, 'Happiness Score'].mean(),
    df2016.loc[:, 'Happiness Score'].mean(),
    df2017.loc[:, 'Happiness.Score'].mean(),
    df2018.loc[:, "Score"].mean(),
    df2019.loc[:, "Score"].mean()
]
jahre = [2015,2016,2017,2018,2019]
dfmean = pd.DataFrame({'Year': jahre, 'Mean Happiness Score': medium})   

dfmean
# Out:
#    Year  Mean Happiness Score
# 0  2015              5.375734
# 1  2016              5.382185
# 2  2017              5.354019
# 3  2018              5.375917
# 4  2019              5.407096

# %%
mittel30last = [
    df2015.loc[120:, 'Happiness Score'].mean(),
    df2016.loc[120:, 'Happiness Score'].mean(),
    df2017.loc[120:, 'Happiness.Score'].mean(),
    df2018.loc[120:, "Score"].mean(),
    df2019.loc[120:, "Score"].mean()
]
jahre = [2015,2016,2017,2018,2019]
dfmeanlast30 = pd.DataFrame({'Year': jahre, 'Mean Happiness Score': mittel30last})

# %%
sns.lineplot(x="Year", y= "Mean Happiness Score", data= dfmeanlast30)
sns.lineplot(x="Year", y= "Mean Happiness Score", data= dfmean)
# Out:
# <Axes: xlabel='Year', ylabel='Mean Happiness Score'>

# %%
top10= [
    df2015.loc[:10, 'Country'],
    df2016.loc[:10, 'Country'],
    df2017.loc[:10, 'Country'],
    df2018.loc[:10, "Country or region"],
    df2019.loc[:10, "Country or region"]
]

# %%
# Out:
# [0     Switzerland
#  1         Iceland
#  2         Denmark
#  3          Norway
#  4          Canada
#  5         Finland
#  6     Netherlands
#  7          Sweden
#  8     New Zealand
#  9       Australia
#  10         Israel
#  Name: Country, dtype: object,
#  0         Denmark
#  1     Switzerland
#  2         Iceland
#  3          Norway
#  4         Finland
#  5          Canada
#  6     Netherlands
#  7     New Zealand
#  8       Australia
#  9          Sweden
#  10         Israel
#  Name: Country, dtype: object,
#  0          Norway
#  1         Denmark
#  2         Iceland
#  3     Switzerland
#  4         Finland
#  5     Netherlands
#  6          Canada
#  7     New Zealand
#  8          Sweden
#  9       Australia
#  10         Israel
#  Name: Country, dtype: object,
#  0            Finland
#  1             Norway
#  2            Denmark
#  3            Iceland
#  4        Switzerland
#  5        Netherlands
#  6             Canada
#  7        New Zealand
#  8             Sweden
#  9          Australia
#  10    United Kingdom
#  Name: Country or region, dtype: object,
#  0         Finland
#  1         Denmark
#  2          Norway
#  3         Iceland
#  4     Netherlands
#  5     Switzerland
#  6          Sweden
#  7     New Zealand
#  8          Canada
#  9         Austria
#  10      Australia
#  Name: Country or region, dtype: object]
